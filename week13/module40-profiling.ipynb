# %%
import pandas as pd
liver = pd.read_csv('https://hds5210-data.s3.amazonaws.com/indian_liver_patient.csv')

# %% [markdown]
# # Basic Descriptive Stats

# %%
liver = liver.groupby('Dataset')

# %%
liver.describe().stack(level=0)
# Out:
#                                        25%     50%      75%  count     max  \
# Dataset
# 1       Age                          34.00   46.00   58.000  416.0    90.0
#         Alamine_Aminotransferase     25.00   41.00   76.500  416.0  2000.0
#         Albumin                       2.50    3.00    3.625  416.0     5.5
#         Albumin_and_Globulin_Ratio    0.70    0.90    1.100  414.0     2.8
#         Alkaline_Phosphotase        186.00  229.00  315.250  416.0  2110.0
#         Aspartate_Aminotransferase   29.75   52.50  108.750  416.0  4929.0
#         Direct_Bilirubin              0.20    0.50    1.800  416.0    19.7
#         Total_Bilirubin               0.80    1.40    3.625  416.0    75.0
#         Total_Protiens                5.70    6.55    7.200  416.0     9.6
# 2       Age                          28.00   40.00   55.000  167.0    85.0
#         Alamine_Aminotransferase     20.00   27.00   37.500  167.0   181.0
# ...

# %% [markdown]
# # Using a PairPlot

# %%
import seaborn as sns

# %%
sns.pairplot(pd.read_csv('https://hds5210-data.s3.amazonaws.com/indian_liver_patient.csv'))

# %% [markdown]
# # Using pandas_profiling

# %%
# !pip install pandas_profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 1.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.5/357.5 kB 14.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.6/381.6 kB 22.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 12.1 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 649.9/649.9 kB 29.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 21.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 21.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 26.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 19.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...

# %%
import pandas_profiling
liver = pd.read_csv('https://hds5210-data.s3.amazonaws.com/indian_liver_patient.csv')
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# /Users/paul/Documents/Workspace/SLUCOR/2023-public/week13/module40-profiling.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/paul/Documents/Workspace/SLUCOR/2023-public/week13/module40-profiling.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> import pandas_profiling
#       <a href='vscode-notebook-cell:/Users/paul/Documents/Workspace/SLUCOR/2023-public/week13/module40-profiling.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> liver = pd.read_csv('https://hds5210-data.s3.amazonaws.com/indian_liver_patient.csv')
#
# File ~/Documents/Workspace/Amitech/payermrf/.venv/lib/python3.9/site-packages/pandas_profiling/__init__.py:8
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
#       6 from warnings import warn
# ----> 8 from pandas_profiling.compare_reports import compare
# ...

# %%
pandas_profiling.ProfileReport(liver, html={'style':{'full_width':True}})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/paul/Documents/Workspace/SLUCOR/2023-public/week13/module40-profiling.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/paul/Documents/Workspace/SLUCOR/2023-public/week13/module40-profiling.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> pandas_profiling.ProfileReport(liver, html={'style':{'full_width':True}})
#
# NameError: name 'pandas_profiling' is not defined
